# %% [markdown]
# # Final project
#
# ## Populaiton of Pittsburgh neighbor
#
# ### Haoliang Cheng

# %% [markdown]
# ----

# %% [markdown]
# 1. Import important packages in python

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Import pupulation dataset

# %%
df_population= pd.read_csv("https://data.wprdc.org/dataset/5b18c198-474c-4723-b735-cc5220ad43cc/resource/82f29015-6905-4b1c-8300-afe9bb2231b3/download/total-population.csv")

# %% [markdown]
# 3. show dataset in table format

# %%
df_population
# Out:
#            Neighborhood  Id  Estimate; Total  Margin of Error; Total
# 0      Allegheny Center   1           1411.0              196.000000
# 1        Allegheny West   2            343.0               96.000000
# 2             Allentown   3           2558.0              449.773276
# 3             Arlington   4           1852.0              348.188168
# 4     Arlington Heights   5            272.0              126.000000
# ..                  ...  ..              ...                     ...
# 86  Upper Lawrenceville  87           2754.0              435.708618
# 87             West End  88            235.0              138.000000
# 88         West Oakland  89           1717.0              285.001754
# 89             Westwood  90           3537.0              407.982843
# 90              Windgap  91           1534.0              367.828765
#
# [91 rows x 4 columns]

# %%
df_population.dtypes
# Out:
# Neighborhood               object
# Id                          int64
# Estimate; Total           float64
# Margin of Error; Total    float64
# dtype: object

# %% [markdown]
# 4.  show dataset in graph format

# %%
fig = plt.figure(figsize=(10, 6))
#plt.bar(df['EST'],df['Mean Humidity'], align = 'center') # doesn't guarantee proper ordering
plt.bar(range(len(df_population['Neighborhood'])),df_population['Estimate; Total'], align = 'center')
plt.xticks(range(len(df_population['Neighborhood'])), df_population['Neighborhood'],\
               rotation = 90, fontsize = 8)
plt.xlabel('neighborhood name')
plt.ylabel('population')
plt.title('population in different neighborhood in Pittsburgh')
plt.show()
# Out:
# Text(0.5, 1.0, 'population in different neighborhood in Pittsburgh')

# %% [markdown]
# 5. Data Analysis

# %%
data_sorted = df_population.sort_values(['Estimate; Total'], ascending=False)
data_sorted
# Out:
#            Neighborhood  Id  Estimate; Total  Margin of Error; Total
# 77  Squirrel Hill South  78          16042.0              889.712313
# 68            Shadyside  69          13562.0              861.984919
# 13            Brookline  14          13160.0              943.065215
# 76  Squirrel Hill North  77          11336.0              767.783173
# 15              Carrick  16          10122.0              826.666196
# ..                  ...  ..              ...                     ...
# 78            St. Clair  79            270.0               96.000000
# 87             West End  88            235.0              138.000000
# 57          North Shore  58            205.0               66.753277
# 71          South Shore  72             12.0               14.000000
# 21              Chateau  22              3.0                3.000000
#
# [91 rows x 4 columns]

# %%
mean=df_population['Estimate; Total'].mean()
print("The average population in each neighborhood is "+str(mean))
median=df_population['Estimate; Total'].median()
print("The median population in each neighborhood is "+str(median))
min=df_population['Estimate; Total'].min()
print("The min population in each neighborhood is "+str(min)+". It is Chateau.")
max=df_population['Estimate; Total'].max()
print("The max population in each neighborhood is "+str(max)+". It is Squirrel Hill South.")
sum=df_population['Estimate; Total'].sum()
print("The sum population in Pittsburgh is "+str(sum))
# Out:
# The average population in each neighborhood is 3399.197802197802
# The median population in each neighborhood is 2456.0
# The min population in each neighborhood is 3.0. It is Chateau.
# The max population in each neighborhood is 16042.0. It is Squirrel Hill South.
# The sum population in Pittsburgh is 309327.0

# %% [markdown]
# 5. Conclusion
